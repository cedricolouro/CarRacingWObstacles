# %% [markdown]
# #Assignment 3 (Part I)

# %% [markdown]
# Install dependencies

# %%
# %rm -rf CarRacingWObstacles
# !git clone https://github.com/luisgarrote/CarRacingWObstacles.git
# Out:
# UsageError: Line magic function `%rm` not found.

# %%
# !pip install swig
# Out:
# Requirement already satisfied: swig in c:\users\cedri\appdata\local\programs\python\python313\lib\site-packages (4.4.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\cedri\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
# %cd CarRacingWObstacles

# !pip install -r requirements.txt
# Out:
# [WinError 2] O sistema não conseguiu localizar o ficheiro especificado: 'CarRacingWObstacles'
# c:\Users\cedri\Documents\GitHub\CarRacingWObstacles
# Requirement already satisfied: swig in c:\users\cedri\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: pygame in c:\users\cedri\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: box2d in c:\users\cedri\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 3)) (2.3.10)
# Requirement already satisfied: gymnasium in c:\users\cedri\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 4)) (1.2.3)
# Requirement already satisfied: numpy in c:\users\cedri\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 5)) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\cedri\appdata\local\programs\python\python313\lib\site-packages (from gymnasium->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\cedri\appdata\local\programs\python\python313\lib\site-packages (from gymnasium->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\cedri\appdata\local\programs\python\python313\lib\site-packages (from gymnasium->-r requirements.txt (line 4)) (0.0.4)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\cedri\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %% [markdown]
# Imports

# %%
pip install -e .
# Out:
# Obtaining file:///C:/Users/cedri/Documents/GitHub/CarRacingWObstacles
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: gymnasium in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from car_racing_obstacles==0.1.0) (1.2.3)
# Requirement already satisfied: box2d in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from car_racing_obstacles==0.1.0) (2.3.10)
# Requirement already satisfied: pygame in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from car_racing_obstacles==0.1.0) (2.6.1)
# Requirement already satisfied: numpy in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from car_racing_obstacles==0.1.0) (2.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from gymnasium->car_racing_obstacles==0.1.0) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from gymnasium->car_racing_obstacles==0.1.0) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from gymnasium->car_racing_obstacles==0.1.0) (0.0.4)
# Installing collected packages: car_racing_obstacles
#   Attempting uninstall: car_racing_obstacles
#     Found existing installation: car_racing_obstacles 0.1.0
#     Uninstalling car_racing_obstacles-0.1.0:
#       Successfully uninstalled car_racing_obstacles-0.1.0
#   Running setup.py develop for car_racing_obstacles
# Successfully installed car_racing_obstacles-0.1.0
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Legacy editable install of car_racing_obstacles==0.1.0 from file:///C:/Users/cedri/Documents/GitHub/CarRacingWObstacles (setup.py develop) is deprecated. pip 25.3 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from matplotlib.pyplot import figure

import gymnasium as gym
import torch
from torch.utils import data
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
import random
from gymnasium import wrappers
import copy
from gymnasium.wrappers import RecordVideo

import glob
import io
import base64
from IPython.display import HTML
from IPython import display as ipythondisplay

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

from car_racing_obstacles import CarRacingObstacles
gym.register(
    id="CarRacingObstacles-v3",
    entry_point="car_racing_obstacles:CarRacingObstacles",
)

print(device)


obstacle_config = {
    #"n_dynamic_obstacles": 5,
    "n_static_obstacles": 5,
    "n_mountains": 5,
    "obstacle_scale": 0.2,
    "use_ghost": False
}
# Out:
# cuda:0
# c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\gymnasium\envs\registration.py:636: UserWarning: WARN: Overriding environment CarRacingObstacles-v3 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %% [markdown]
# Deep RL Replay Buffer

# %%
class ReplayBuffer:
    def __init__(self, size):
        self.size = size
        self.counter = 0
        self.state_buffer = []
        self.action_buffer = []
        self.reward_buffer = []
        self.new_state_buffer = []
        self.terminal_buffer = []

    def store_tuples(self, state, action, reward, new_state, done):
        if len(self.state_buffer) < self.size:
            self.state_buffer.append(None)
            self.action_buffer.append(None)
            self.reward_buffer.append(None)
            self.new_state_buffer.append(None)
            self.terminal_buffer.append(None)

        self.counter = self.counter % self.size
        self.state_buffer[self.counter] = state
        self.action_buffer[self.counter] = action
        self.reward_buffer[self.counter] = reward
        self.new_state_buffer[self.counter] = new_state
        self.terminal_buffer[self.counter] = done
        self.counter += 1

    def sample_buffer(self, batch_size):
        max_buffer = min(self.counter, self.size)
        batch = np.random.choice(max_buffer, batch_size, replace=False)
        state_batch=[];
        action_batch=[];
        reward_batch=[];
        new_state_batch=[];
        done_batch=[];

        for a in batch:
            state_batch.append(self.state_buffer[a])
            action_batch.append(self.action_buffer[a])
            reward_batch.append(self.reward_buffer[a])
            new_state_batch.append(self.new_state_buffer[a])
            done_batch.append(self.terminal_buffer[a])
        return state_batch, action_batch, reward_batch, new_state_batch, done_batch

# %% [markdown]
# Default DQN arquitecture
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## CNN 1

# %%
from torchvision import datasets, models
class DQN(nn.Module):

    def __init__(self, inputs, outputs):
        super(DQN, self).__init__()

        self.input_size=inputs;
        self.output_size=outputs;


        self.features = nn.Sequential(
                                   #Add code here for DQN
                                   #you can use the same code for dueling
            nn.Conv2d(inputs, 6, 7,stride=3, padding=1),  # Conv1
            nn.ReLU(True),
            nn.MaxPool2d(2,2),  # Conv1
            nn.Conv2d(6, 12, 4, padding=1),  # Conv1
            nn.ReLU(True),
            nn.MaxPool2d(2,2),  # Conv1
        )

        self.layers = nn.Sequential(nn.Linear(588, 128),
            nn.ReLU(),
            nn.Linear(128, outputs)
        )


        self.layersdueling = nn.Sequential(
            nn.Linear( 588, 128),
            nn.ReLU()
        )


        self.advantage = nn.Sequential(
            nn.Linear(128, outputs)
        )

        self.value = nn.Sequential(
            nn.Linear(128, 1)
        )

###### DQN/Double DQN configuration

###########    ############    #################
#         #    #          #    #               #
#   IMG   # -> # features # -> #     layers    #    .... argmax ....
#         #    #  (CONVs) #    #     (FCs)     #
###########    ############    #################


###### Dueling configuration
                                                    #############
###########    ############    #################    # advantage #
#         #    #          #    #               # -> #############   ... value + advantage  - advantage.mean() ... argmax ...
#   IMG   # -> # features # -> # layersdueling # -> #############
#         #    #  (CONVs) #    #     (FCs)     #    #   value   #
###########    ############    #################    #############





    def forward(self, x):  # primeiras alteracoes para ter QN


        x = self.features(x) # normal para passar pelas conv layers

        x = x.view(x.size(0), -1) # dar flat para as conv layers

        if useDueling: # DQN ou Dueling 
            x = self.layersdueling(x)
            advantage = self.advantage(x)
            value = self.value(x)
            return value + advantage - advantage.mean(dim=1, keepdim=True) # Q(s,a) = V(s) + (A(s,a) - mean(A(s,a))) formula enunciado
        
        else:
            x = self.layers(x)
            return x






    def policy(self,state):
       with torch.no_grad():
            return self.__call__(state.unsqueeze(0)).argmax()

    def getPolicy(self,state,eps_threshold):
        sample = random.random()
        if sample > eps_threshold:
            with torch.no_grad():
                return self.__call__(state.unsqueeze(0)).argmax()
        else:
            return  torch.tensor(random.randrange(self.output_size), device=device, dtype=torch.long)

# %% [markdown]
# ## CNN 2

# %%
from torchvision import datasets, models
class DQN(nn.Module):
    def __init__(self, inputs, outputs):
        super(DQN, self).__init__()



        self.input_size=inputs;
        self.output_size=outputs;



        self.features = nn.Sequential(
            nn.Conv2d(inputs, 32, kernel_size=8, stride=4), # Downsamples 96 -> 23
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),    # Downsamples 23 -> 10
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),    # Downsamples 10 -> 8
            nn.ReLU()
        )


        self.flat_size = 4096 


        self.layers = nn.Sequential(nn.Linear(self.flat_size, 256),
            nn.ReLU(),
            nn.Linear(256, outputs)
        )


        self.layersdueling = nn.Sequential(
            nn.Linear(self.flat_size, 256),
            nn.ReLU()
        )


        self.advantage = nn.Sequential(
            nn.Linear(256, outputs)
        )

        self.value = nn.Sequential(
            nn.Linear(256, 1)
        )




###### DQN/Double DQN configuration

###########    ############    #################
#         #    #          #    #               #
#   IMG   # -> # features # -> #     layers    #    .... argmax ....
#         #    #  (CONVs) #    #     (FCs)     #
###########    ############    #################


###### Dueling configuration
                                                    #############
###########    ############    #################    # advantage #
#         #    #          #    #               # -> #############   ... value + advantage  - advantage.mean() ... argmax ...
#   IMG   # -> # features # -> # layersdueling # -> #############
#         #    #  (CONVs) #    #     (FCs)     #    #   value   #
###########    ############    #################    #############





    def forward(self, x):  # primeiras alteracoes para ter QN


        x = self.features(x) # normal para passar pelas conv layers

        x = x.view(x.size(0), -1) # dar flat para as conv layers

        if useDueling: # DQN ou Dueling
            x = self.layersdueling(x)
            advantage = self.advantage(x)
            value = self.value(x)
            return value + advantage - advantage.mean(dim=1, keepdim=True) # Q(s,a) = V(s) + (A(s,a) - mean(A(s,a))) formula enunciado

        else:
            x = self.layers(x)
            return x






    def policy(self,state):
       with torch.no_grad():
            return self.__call__(state.unsqueeze(0)).argmax()

    def getPolicy(self,state,eps_threshold):
        sample = random.random()
        if sample > eps_threshold:
            with torch.no_grad():
                return self.__call__(state.unsqueeze(0)).argmax()
        else:
            return  torch.tensor(random.randrange(self.output_size), device=device, dtype=torch.long)

# %% [markdown]
# ## CNN 3

# %%
from torchvision import datasets, models
class DQN(nn.Module):

    def __init__(self, inputs, outputs, H=96, W=96):
        super(DQN, self).__init__()

        self.input_size=inputs;
        self.output_size=outputs;


        self.features = nn.Sequential(

            nn.Conv2d(inputs, 32, kernel_size=8, stride=4), # Conv1
            nn.ReLU(),

            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),

            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
        )

        with torch.no_grad():
            dummy = torch.zeros(1, inputs, H, W)
            n_flat = self.features(dummy).view(1, -1).size(1)


        self.fc = nn.Sequential(
            nn.Linear(n_flat, 512),
            nn.ReLU()
        )


        self.advantage = nn.Linear(512, outputs)
        

        self.value = nn.Linear(512, 1)
        

###### DQN/Double DQN configuration

###########    ############    #################
#         #    #          #    #               #
#   IMG   # -> # features # -> #     layers    #    .... argmax ....
#         #    #  (CONVs) #    #     (FCs)     #
###########    ############    #################


###### Dueling configuration
                                                    #############
###########    ############    #################    # advantage #
#         #    #          #    #               # -> #############   ... value + advantage  - advantage.mean() ... argmax ...
#   IMG   # -> # features # -> # layersdueling # -> #############
#         #    #  (CONVs) #    #     (FCs)     #    #   value   #
###########    ############    #################    #############





    def forward(self, x):  # primeiras alteracoes para ter QN


        x = self.features(x) # normal para passar pelas conv layers

        x = x.view(x.size(0), -1) # dar flat para as conv layers

        x = self.fc(x)

        if useDueling: # DQN ou Dueling 
            advantage = self.advantage(x)
            value = self.value(x)
            return value + advantage - advantage.mean(dim=1, keepdim=True) # Q(s,a) = V(s) + (A(s,a) - mean(A(s,a))) formula enunciado
        
        else:
            x = self.advantage(x)
            return x




    def policy(self,state):
       with torch.no_grad():
            return self.__call__(state.unsqueeze(0)).argmax()

    def getPolicy(self,state,eps_threshold):
        sample = random.random()
        if sample > eps_threshold:
            with torch.no_grad():
                return self.__call__(state.unsqueeze(0)).argmax()
        else:
            return  torch.tensor(random.randrange(self.output_size), device=device, dtype=torch.long)

# %%
from IPython.display import HTML
HTML('<iframe width="1297" height="865" src="https://www.youtube.com/embed/kXXdMlyP4OE" title="APA2025 - CarRacingObstacles-v3" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>')
# Out:
# c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\IPython\core\display.py:447: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="1297" height="865" src="https://www.youtube.com/embed/kXXdMlyP4OE" title="APA2025 - CarRacingObstacles-v3" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
def createMovie(Network,Filename,UseRandomizer,UseContinuous):

    env1 = gym.make("CarRacingObstacles-v3", render_mode="rgb_array",domain_randomize=UseRandomize,
                    continuous=UseContinuousControl, **obstacle_config)
    envX = env1
    envX = RecordVideo(env1, video_folder='./videos/'+Filename,  episode_trigger = lambda x: True)

    new_state = envX.reset(options={"randomize": UseRandomizer})


    stackedStateX=[np.rollaxis(new_state[0], 2, 0).copy() for i in range(FrameStack)];
    state =torch.from_numpy(np.reshape(np.array(stackedStateX),(FrameSize*FrameStack,96,96)) ).float().to(device)


    i=0
    Network.eval()
    resetStatus=0;


    while True:
        envX.render()

        action = Network.policy(state);
        reward=0
        for x in range(ControlSteps):
            new_state, r, done, truncated, _  = envX.step(action_space[action.item()])
            reward+=r
            if(done or truncated):
                break
        stackedStateX.pop(0)


        stackedStateX.append(np.rollaxis(new_state, 2, 0).copy())
        state=torch.from_numpy(np.reshape(np.array(stackedStateX),(FrameSize*FrameStack,96,96))).float().to(device)
        i=i+1;
        if done or truncated:
          break;

    envX.close()
    env1.close();
    Network.train()
    mp4list = glob.glob('./videos/'+Filename+'/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

# %% [markdown]
# Dummy Net with random policy

# %%
class RandomNet(nn.Module):

    def __init__(self,outputs):
        super(RandomNet, self).__init__()
        self.output_size=outputs;


    def forward(self, x):
        return  x

    def policy(self,state):
       return  torch.tensor([[random.randrange(self.output_size)]], device=device, dtype=torch.long)

# %% [markdown]
# Parameters

# %%
###################################################
###################################################
###################################################
UseRandomize=False; # default é false, testar a true com o melhor modelo
UseContinuousControl=True; # Primeiro foi testado com True, agora com false, TRUE conseguiu melhores resultados
###################################################
###################################################
###################################################


if UseContinuousControl:
    #action space is still discretized however more actions can be selected
    action_space    = [
            np.array([-1, 1, 0.2]), np.array([0, 1, 0.2]), np.array([1, 1, 0.2]), #           Action Space Structure
            np.array([-1, 1,   0]), np.array([0, 1,   0]), np.array([1, 1,   0]), #        (Steering Wheel, Gas, Break)
            np.array([-1, 0, 0.2]), np.array([0, 0, 0.2]), np.array([1, 0, 0.2]), # Range        -1~1       0~1   0~1
            np.array([-1, 0,   0]), np.array([0, 0,   0]), np.array([1, 0,   0]) ];


else:
    action_space=[0,1,2,3,4]    #  nothing','left','right','gas','brake'

n_actions=len(action_space)

#hyper-parameters
TotalEpisodes=2000;
MaxSteps=1000;
ControlSteps=3; # number of iterations the same action is executed in the environment
FrameStack=4 # number of consecutive frames used to represent the state
FreezeCounter=50; # clone the model every X episodes
BatchSize=64; # testar com 128 !!
exploration_threshold=1
exploration_threshold_min=0.01
exploration_decay=0.985  # default era 0.985
discount_factor=0.99 # valor a alterar para tentar obter melhores resultados, default era 0.95
LearningRate=0.0001 # valor default .0001 (^-4)

SaveAtCounter=50 # save model or video at every X episodes
ResetCounter=30 # maximum number of experiences with bad performance (max=InitCounter+ResetCounter)
InitCounter=30 # minimum number of experiences per episode
FrameSize=3; # 3 if RGB 1 if grayscale

BufferSize=20000  # max number of experiences in the buffer (may need to be smaller if CUDA memory errors occur).


# use these flags to enable Double DQN and Duelinng (Dueling DQN or Double Dueling DQN)
usedoubleDQN=True
useDueling=True

# %% [markdown]
# Run the new netwwork with random policy

# %%
pip install moviepy
# Out:
# Requirement already satisfied: moviepy in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (2.2.1)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from moviepy) (5.2.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from moviepy) (2.37.2)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: numpy>=1.25.0 in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from moviepy) (2.0.1)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from moviepy) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from moviepy) (1.2.1)
# Requirement already satisfied: pillow<12.0,>=9.2.0 in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from moviepy) (11.1.0)
# Requirement already satisfied: tqdm in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from proglog<=1.0.0->moviepy) (4.67.1)
# Requirement already satisfied: colorama in c:\users\cedri\anaconda3\envs\pytorch_env\lib\site-packages (from tqdm->proglog<=1.0.0->moviepy) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
randomnet=RandomNet(n_actions)
createMovie(randomnet,"random",UseRandomize,UseContinuousControl)
# Out:
# c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at c:\Users\cedri\Documents\GitHub\CarRacingWObstacles\videos\random folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# Initialization and Parameters:

# %%
env = gym.make("CarRacingObstacles-v3", render_mode="rgb_array",domain_randomize=UseRandomize,
                    continuous=UseContinuousControl, **obstacle_config)
spec = gym.spec("CarRacingObstacles-v3")


#network DQN
policy_net = DQN(FrameSize*FrameStack, n_actions).to(device)
target_net = DQN(FrameSize*FrameStack, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

buffer = ReplayBuffer(BufferSize);

optimizer = torch.optim.Adam(policy_net.parameters(), lr=LearningRate)
loss=  torch.nn.SmoothL1Loss()

# %% [markdown]
# DQN training

# %%
def trainModel(buffer_data):
    if buffer_data.counter < BatchSize:
        return 0.0

    state_batch, action_batch, reward_batch, new_state_batch, done_batch = buffer_data.sample_buffer(BatchSize)
    state_batch = torch.stack(state_batch).to(device)
    action_batch = torch.stack(action_batch).reshape(-1,1).to(device)
    new_state_batch = torch.stack(new_state_batch).to(device)
    reward_batch = torch.stack(reward_batch).reshape(-1,1).to(device)
    done_batch = torch.stack(done_batch).reshape(-1,1).to(device)


    q_values = policy_net(state_batch)
    q_value = q_values.gather(1, action_batch)

    # Target Q values
    with torch.no_grad():
        if usedoubleDQN:
            next_actions = policy_net(new_state_batch).argmax(dim=1, keepdim=True)
            next_q_values = target_net(new_state_batch).gather(1, next_actions)
        else:
            next_q_values = target_net(new_state_batch).max(1, keepdim=True)[0]

        target_q = reward_batch + discount_factor * next_q_values * (1 - done_batch)

    # Loss
    loss_value = loss(q_value, target_q)

    optimizer.zero_grad()
    loss_value.backward()

    torch.nn.utils.clip_grad_norm_(policy_net.parameters(), 1.0) # estabilizar gradientes

    optimizer.step()

    return loss_value.item()

# %% [markdown]
# DeepRL Loop

# %%
loss_val,scores, episodes,events, avg_scores,avg_scores20,exploration = [],[],[], [],[], [], []

bestScore=-99999;
at=0;


for f in range(TotalEpisodes):
    done  = False
    score = 0.0
    tloss = 0.0

    new_state,_=env.reset(options={"randomize": UseRandomize})#,seed=6)


    stackedState=[np.rollaxis(new_state, 2, 0).copy() for i in range(FrameStack)];
    state =torch.from_numpy(np.reshape(np.array(stackedState),(FrameSize*FrameStack,96,96)) ).float().to(device)

    if f % FreezeCounter == 0:
       print("########################################"+str(f)+" of "+str(TotalEpisodes))
       target_net.load_state_dict(policy_net.state_dict())

    if f % SaveAtCounter == 0:
      #torch.save(policy_net.state_dict(), "v2CarRacing_"+str(f)+'_model.ckpt')
       createMovie(policy_net,"CarRacing_"+str(f),UseRandomize,UseContinuousControl)

    resetStatus=0;
    i=0

    for F in range(MaxSteps):
        #env.render()
        action = policy_net.getPolicy(state,exploration_threshold)
        reward=0
        for _ in range(ControlSteps):
            new_state, r, done,trunc, info = env.step(action_space[action.item()])
            reward+=r
            i=i+1
            if(done or trunc):
                break
        if reward<0 and i>InitCounter:
            resetStatus=resetStatus+1;
        else:
            resetStatus=0

        stackedState.pop(0)
        stackedState.append(np.rollaxis(new_state, 2, 0).copy())
        new_state=torch.from_numpy(np.reshape(np.array(stackedState),(FrameSize*FrameStack,96,96))).float().to(device)

        score += reward
        if(F<(MaxSteps-1)):
            buffer.store_tuples(state, action, torch.tensor(reward), new_state, torch.tensor(int(done)))

        state = new_state
        trainModel(buffer)


        if(done or trunc or resetStatus>=ResetCounter):
            break
    exploration_threshold= exploration_threshold*exploration_decay if exploration_threshold > exploration_threshold_min else exploration_threshold_min

    if(score>bestScore):
        print("Best EP: ",score," It: ",F*ControlSteps)
        bestScore=score;
        torch.save(policy_net.state_dict(), "BestCarRacing_best_model.ckpt")
        at=f;

    exploration.append(exploration_threshold)
    scores.append(score)
    episodes.append(f)
    events.append(F)
    avg_scores.append(score/F)
    avg_scores20.append(np.mean(scores[-20:]))


policy_net.load_state_dict(torch.load("BestCarRacing_best_model.ckpt", weights_only=True))
# Out:
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 61
# [CarRacingObstacles] Placed mountain around tile 123
# [CarRacingObstacles] Placed mountain around tile 185
# [CarRacingObstacles] Placed mountain around tile 247
# ########################################0 of 2000
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 66
# [CarRacingObstacles] Placed mountain around tile 132
# [CarRacingObstacles] Placed mountain around tile 199
# [CarRacingObstacles] Placed mountain around tile 265
# c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\gymnasium\wrappers\rendering.py:434: UserWarning: WARN: Unable to save last video! Did you call close()?
#   logger.warn("Unable to save last video! Did you call close()?")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 24
#      20    target_net.load_state_dict(policy_net.state_dict())
#      22 if f % SaveAtCounter == 0:
#      23   #torch.save(policy_net.state_dict(), "v2CarRacing_"+str(f)+'_model.ckpt')
# ---> 24    createMovie(policy_net,"CarRacing_"+str(f),UseRandomize,UseContinuousControl)
#      26 resetStatus=0;
#      27 i=0
#
# Cell In[17], line 26, in createMovie(Network, Filename, UseRandomizer, UseContinuous)
#      24 reward=0
#      25 for x in range(ControlSteps):
# ---> 26     new_state, r, done, truncated, _  = envX.step(action_space[action.item()])
#      27     reward+=r
#      28     if(done or truncated):
#
# File c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\gymnasium\wrappers\rendering.py:363, in RecordVideo.step(self, action)
#     359 def step(
#     360     self, action: ActType
#     361 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     362     """Steps through the environment using action, recording observations if :attr:`self.recording`."""
# --> 363     obs, rew, terminated, truncated, info = self.env.step(action)
#     364     self.step_id += 1
#     366     if self.step_trigger and self.step_trigger(self.step_id):
#
# File c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File c:\Users\cedri\Documents\GitHub\CarRacingWObstacles\car_racing_obstacles.py:351, in CarRacingObstacles.step(self, action)
#     349 def step(self, action):
#     350     # Run original CarRacing step (physics + base reward logic)
# --> 351     obs, reward, terminated, truncated, info = super().step(action)
#     353     dt = 1.0 / FPS
#     355     # ---- 1) Static collisions: big penalty + terminate ----
#
# File c:\Users\cedri\Documents\GitHub\CarRacingWObstacles\car_racing.py:565, in CarRacing.step(self, action)
#     562 self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     563 self.t += 1.0 / FPS
# --> 565 self.state = self._render("state_pixels")
#     567 step_reward = 0
#     568 terminated = False
#
# File c:\Users\cedri\Documents\GitHub\CarRacingWObstacles\car_racing.py:644, in CarRacing._render(self, mode)
#     641 # showing stats
#     642 self._render_indicators(WINDOW_W, WINDOW_H)
# --> 644 font = pygame.font.Font(pygame.font.get_default_font(), 42)
#     645 text = font.render("%04i" % self.reward, True, (255, 255, 255), (0, 0, 0))
#     646 text_rect = text.get_rect()
#
# File c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\pygame\pkgdata.py:65, in getResource(identifier, pkgname)
#      62 # When pyinstaller (or similar tools) are used, resource_exists may raise
#      63 # NotImplemented error
#      64 try:
# ---> 65     if resource_exists(pkgname, identifier):
#      66         return resource_stream(pkgname, identifier)
#      67 except NotImplementedError:
#
# File c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\pkg_resources\__init__.py:1368, in ResourceManager.resource_exists(self, package_or_requirement, resource_name)
#    1364 def resource_exists(
#    1365     self, package_or_requirement: _PkgReqType, resource_name: str
#    1366 ) -> bool:
#    1367     """Does the named resource exist?"""
# -> 1368     return get_provider(package_or_requirement).has_resource(resource_name)
#
# File c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\pkg_resources\__init__.py:1681, in NullProvider.has_resource(self, resource_name)
#    1680 def has_resource(self, resource_name: str) -> bool:
# -> 1681     return self._has(self._fn(self.module_path, resource_name))
#
# File c:\Users\cedri\anaconda3\envs\pytorch_env\Lib\site-packages\pkg_resources\__init__.py:1899, in DefaultProvider._has(self, path)
#    1898 def _has(self, path) -> bool:
# -> 1899     return os.path.exists(path)
#
# File <frozen genericpath>:19, in exists(path)
#
# KeyboardInterrupt:

# %% [markdown]
# Plot performance

# %%
figure(figsize=(12, 6), dpi=80)
plt.plot(episodes, scores)
plt.plot(episodes, events)
plt.plot(episodes, avg_scores)
plt.plot(episodes, avg_scores20)
plt.plot(episodes, exploration)


plt.axhline(y=900, color='yellow', linestyle='--', linewidth=2)
plt.axhline(y=200, color='grey', linestyle='--', linewidth=2)
plt.axhline(y=500, color='black', linestyle='--', linewidth=2)

plt.xlabel('episodes')
plt.ylabel('Score')

plt.title('Track Locked DQN '+str(usedoubleDQN)+' '+str(useDueling))
plt.legend(['scores', 'events', 'avg_scores', 'avg_scores100','exploration'])
plt.show()

# %% [markdown]
# View Best Results

# %%
policy_net.eval()

createMovie(policy_net,'bestNet',UseRandomize,UseContinuousControl)
# Out:
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 54
# [CarRacingObstacles] Placed mountain around tile 109
# [CarRacingObstacles] Placed mountain around tile 164
# [CarRacingObstacles] Placed mountain around tile 219
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
def evaluate(Network,UseRandomizer,UseContinuous,seedTest):

    env1 = gym.make("CarRacingObstacles-v3", render_mode="rgb_array",domain_randomize=UseRandomize,
                    continuous=UseContinuousControl, **obstacle_config)

        #, n_static_obstacles=10, n_dynamic_obstacles=2, n_mountains=0, obstacle_scale=15, use_ghost=True
    
    envX = env1

    new_state = envX.reset(options={"randomize": UseRandomizer},seed=seedTest)#,seed=6)
    new_state, _ = envX.reset(options={"randomize": UseRandomizer},seed=seedTest)#,seed=6)


    stackedStateX=[np.rollaxis(new_state, 2, 0).copy() for i in range(FrameStack)];
    state =torch.from_numpy(np.reshape(np.array(stackedStateX),(FrameSize*FrameStack,96,96)) ).float().to(device)
                
              

    i=0
    Network.eval()
    resetStatus=0;

    totalreward=0
    while True:
        action = Network.policy(state);
        reward=0
        for x in range(ControlSteps):
            new_state, r, done, truncated, _  = envX.step(action_space[action.item()])
            reward+=r
            if(done):
                break

        totalreward+=reward;
        stackedStateX.pop(0)

        stackedStateX.append(np.rollaxis(new_state, 2, 0).copy())
        state=torch.from_numpy(np.reshape(np.array(stackedStateX),(FrameSize*FrameStack,96,96))).float().to(device)
        i=i+1;
        if done or truncated:
          break;

    envX.close()
    return totalreward;

# %%
print("Total Reward: ",evaluate(policy_net,False,UseContinuousControl,1))
print("Total Reward: ",evaluate(policy_net,False,UseContinuousControl,2))
print("Total Reward: ",evaluate(policy_net,False,UseContinuousControl,3))
print("Total Reward: ",evaluate(policy_net,False,UseContinuousControl,4))
print("Total Reward: ",evaluate(policy_net,False,UseContinuousControl,5))
print("Total Reward: ",evaluate(policy_net,True,UseContinuousControl,6))
print("Total Reward: ",evaluate(policy_net,True,UseContinuousControl,7))
print("Total Reward: ",evaluate(policy_net,True,UseContinuousControl,8))
print("Total Reward: ",evaluate(policy_net,True,UseContinuousControl,9))
print("Total Reward: ",evaluate(policy_net,True,UseContinuousControl,10))
# Out:
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 54
# [CarRacingObstacles] Placed mountain around tile 109
# [CarRacingObstacles] Placed mountain around tile 164
# [CarRacingObstacles] Placed mountain around tile 219
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 54
# [CarRacingObstacles] Placed mountain around tile 109
# [CarRacingObstacles] Placed mountain around tile 164
# [CarRacingObstacles] Placed mountain around tile 219
# Total Reward:  211.1854545454594
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 66
# [CarRacingObstacles] Placed mountain around tile 133
# [CarRacingObstacles] Placed mountain around tile 200
# [CarRacingObstacles] Placed mountain around tile 267
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 66
# [CarRacingObstacles] Placed mountain around tile 133
# [CarRacingObstacles] Placed mountain around tile 200
# [CarRacingObstacles] Placed mountain around tile 267
# Total Reward:  162.27910447761363
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 54
# [CarRacingObstacles] Placed mountain around tile 108
# [CarRacingObstacles] Placed mountain around tile 162
# [CarRacingObstacles] Placed mountain around tile 216
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 54
# [CarRacingObstacles] Placed mountain around tile 108
# [CarRacingObstacles] Placed mountain around tile 162
# [CarRacingObstacles] Placed mountain around tile 216
# Total Reward:  336.5242066420604
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 54
# [CarRacingObstacles] Placed mountain around tile 109
# [CarRacingObstacles] Placed mountain around tile 164
# [CarRacingObstacles] Placed mountain around tile 219
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 54
# [CarRacingObstacles] Placed mountain around tile 109
# [CarRacingObstacles] Placed mountain around tile 164
# [CarRacingObstacles] Placed mountain around tile 219
# Total Reward:  781.4636363636207
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 65
# [CarRacingObstacles] Placed mountain around tile 131
# [CarRacingObstacles] Placed mountain around tile 196
# [CarRacingObstacles] Placed mountain around tile 262
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 65
# [CarRacingObstacles] Placed mountain around tile 131
# [CarRacingObstacles] Placed mountain around tile 196
# [CarRacingObstacles] Placed mountain around tile 262
# Total Reward:  619.2583586626062
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 56
# [CarRacingObstacles] Placed mountain around tile 113
# [CarRacingObstacles] Placed mountain around tile 169
# [CarRacingObstacles] Placed mountain around tile 226
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 56
# [CarRacingObstacles] Placed mountain around tile 113
# [CarRacingObstacles] Placed mountain around tile 169
# [CarRacingObstacles] Placed mountain around tile 226
# Total Reward:  685.6464788732274
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 63
# [CarRacingObstacles] Placed mountain around tile 127
# [CarRacingObstacles] Placed mountain around tile 190
# [CarRacingObstacles] Placed mountain around tile 254
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 63
# [CarRacingObstacles] Placed mountain around tile 127
# [CarRacingObstacles] Placed mountain around tile 190
# [CarRacingObstacles] Placed mountain around tile 254
# Total Reward:  168.67554858934287
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 50
# [CarRacingObstacles] Placed mountain around tile 100
# [CarRacingObstacles] Placed mountain around tile 150
# [CarRacingObstacles] Placed mountain around tile 200
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 50
# [CarRacingObstacles] Placed mountain around tile 100
# [CarRacingObstacles] Placed mountain around tile 150
# [CarRacingObstacles] Placed mountain around tile 200
# Total Reward:  684.2474103585571
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 56
# [CarRacingObstacles] Placed mountain around tile 113
# [CarRacingObstacles] Placed mountain around tile 170
# [CarRacingObstacles] Placed mountain around tile 227
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 56
# [CarRacingObstacles] Placed mountain around tile 113
# [CarRacingObstacles] Placed mountain around tile 170
# [CarRacingObstacles] Placed mountain around tile 227
# Total Reward:  517.8508771929713
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 60
# [CarRacingObstacles] Placed mountain around tile 120
# [CarRacingObstacles] Placed mountain around tile 180
# [CarRacingObstacles] Placed mountain around tile 240
# [CarRacingObstacles] Placed mountain around tile 0
# [CarRacingObstacles] Placed mountain around tile 60
# [CarRacingObstacles] Placed mountain around tile 120
# [CarRacingObstacles] Placed mountain around tile 180
# [CarRacingObstacles] Placed mountain around tile 240
# Total Reward:  258.819468438532
